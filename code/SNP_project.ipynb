# %% [markdown]
# In order to access a shared with you folder or file in Google Colab you have to:
#
# Go to Shared with me in Google Drive.
#
# Select the folder or file you want to acess.
#
# Right click on it and choose Add shortcut to drive.
#
# A pop-up window will apear, Select MyDrive then click on Add Shortcut.
#
# Now, Go to your Google Colab Notebook

# %%
# Mount Google Drive 

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/MyDrive  # You should see SNP project
# Out:
# 'SNP project background'

# %%
# Add the directory to find the codes
import sys
sys.path.append('/content/drive/MyDrive/SNP project background/Codes')

# Import some function
import prepfile as prep  # import the file prepfile.py 
import os
import pi

# %% [markdown]
# # Nouvelle section

# %% [markdown]
# # Nouvelle section

# %%
# In GoogleDrive
path = '/content/drive/MyDrive/SNP project background/Alignment example/'
filename =  'Alignment_format_example.TXT'

# -----------------------------------------------
# Prepare the input file 
#path = os.getcwd()  # in local computer
#filename =  '\\Alignment_format_example.TXT'
df = prep.prepfile(filename=filename, path=path)

# Check the dataframe
print(df.head())

# Check the SNP positions
dictSNP, nbSNP = pi.findSNPpos(df)

# Calculate pi
pi.calculatepi(dictSNP, df)

# 
pi.checksynonymousSNP(dictSNP, df)
# Out:
# The input file is: Alignment_format_example.TXT
#
# Number of genes (before removing missing bases)= 4
# Number of sample= 3
#                                                       psbD  \
# Sample1  [A, T, G, A, C, T, A, T, A, G, C, T, C, T, T, ...
# Sample2  [A, T, G, A, C, T, A, T, A, G, C, T, C, T, T, ...
# Sample3  [A, T, G, A, C, T, A, T, A, G, C, T, C, T, T, ...
#
#                                                       petB  \
# Sample1  [A, T, G, A, G, T, A, A, A, G, T, C, T, A, T, ...
# Sample2  [A, T, G, A, G, T, A, A, A, G, T, C, T, A, T, ...
# Sample3  [A, T, G, A, G, T, A, A, A, G, T, C, T, A, T, ...
#
#                                                       ycf1  \
# Sample1  [A, T, G, A, T, T, T, G, C, A, A, G, T, A, T, ...
# Sample2  [A, T, G, A, T, T, T, G, C, A, A, G, T, A, T, ...
# Sample3  [A, T, G, A, T, T, T, G, C, A, A, G, T, A, T, ...
#
#                                                       ycf2
# Sample1  [A, T, G, A, A, G, A, A, G, A, A, T, G, A, A, ...
# ...

# %%
# Out:
# 1062
